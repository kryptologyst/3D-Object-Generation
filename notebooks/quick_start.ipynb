# %% [markdown]
# # 3D Object Generation - Quick Start
#
# This notebook demonstrates how to use the 3D object generation framework to train models and generate point clouds.

# %%
import torch
import numpy as np
import matplotlib.pyplot as plt
from mpl_toolkits.mplot3d import Axes3D

from src.3dgen import (
    PointCloudDataset,
    get_dataloader,
    PointCloudVAE,
    PointCloudGAN,
    PointCloudGenerator,
    compute_chamfer_distance,
    set_seed,
    get_device,
)

# Set random seed for reproducibility
set_seed(42)

# Get device
device = get_device()
print(f"Using device: {device}")

# %% [markdown]
# ## 1. Create Dataset and Data Loader

# %%
# Create synthetic dataset
dataset = PointCloudDataset(
    num_points=512,
    synthetic=True,
    shape_types=["sphere", "cube", "cylinder"],
    normalize=True,
    augment=True,
)

# Create data loader
dataloader = get_dataloader(
    dataset,
    batch_size=8,
    shuffle=True,
    num_workers=0,
)

print(f"Dataset size: {len(dataset)}")
print(f"Batch size: {dataloader.batch_size}")
